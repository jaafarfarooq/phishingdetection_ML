# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read the Dataset

# %%
df=pd.read_csv('../input/phishing1csv/dataset.csv')
df.head()

# %%
df.head().T

# %% [markdown]
# ### Shape of the Dataset

# %%
df.shape

# %%
df.describe()

# %%
df.info()

# %% [markdown]
# ### Data Preprocessing

# %%
print(df.corr()['Result'].sort_values())

# %%
#drop columns with -0.03<correlation<0.03¶
cols_to_drop=['Redirect','Iframe','Favicon','popUpWidnow','index','RightClick','Submitting_to_email']
df = df.drop(cols_to_drop, axis = 1).copy()
df.head().T

# %%
df.shape

# %%
print(df.corr()['Result'].sort_values())

# %% [markdown]
# # Check For Null values

# %%
df.isnull().sum()

# %% [markdown]
# # Drop rows with null values

# %%
df=df.dropna()

# %%
df.shape

# %% [markdown]
# ### Data Visualization

# %%
df.hist(figsize = (20,20))
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr())
plt.show()

# %% [markdown]
# ## Websites

# %%
sns.countplot(x='Result', data=df,)
plt.show()
print("Legitmate Websites: ",len(df[df['Result']==-1]))
print("Phishing Websites: ",len(df[df['Result']==1]))

# %% [markdown]
# # Splitting Data into Train and Test

# %%
from sklearn.model_selection import train_test_split

# %%
y = np.asarray(df[['Result']])
b=(list(df))
#print(b[:-1])
x = np.asarray(df[b[:-1]])

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# # Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)

# %%
y_pred=dtree.predict(X_test)
y_trainpred=dtree.predict(X_train)

# %% [markdown]
# ### Confusion Matrix and Accuracy for Decision tree

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
cm_dtree=confusion_matrix(y_test,y_pred)
print("True Possitives: ", cm_dtree[0][0],"True Negatives: ",cm_dtree[0][1])
print("False Possitives: ", cm_dtree[1][0],"False Negatives: ",cm_dtree[1][1])
accuracy_dtree=accuracy_score(y_test,y_pred)
print("Decision Tree Accuracy: ",accuracy_dtree)

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()
rfc.fit(X_train,y_train)

# %%
y_pred=rfc.predict(X_test)
y_trainpred=rfc.predict(X_train)

# %% [markdown]
# ### Confusion Matrix and Accuracy for Random Forest Classifier

# %%
cm_rfc=confusion_matrix(y_test,y_pred)
print("True Possitives: ", cm_rfc[0][0],"True Negatives: ",cm_rfc[0][1])
print("False Possitives: ", cm_rfc[1][0],"False Negatives: ",cm_rfc[1][1])
accuracy_rfc=accuracy_score(y_test,y_pred)
print("Training Accuracy: ",y_trainpred)
print("Random Forest Accuracy: ",accuracy_rfc)

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %% [markdown]
# # K-Nearest Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,y_train)

# %%
y_pred=knn.predict(X_test)
y_trainpred=knn.predict(X_train)

# %% [markdown]
# ### Confusion Matrix and Accuracy for KNN

# %%
cm_knn=confusion_matrix(y_test,y_pred)
print("True Possitives: ", cm_knn[0][0],"True Negatives: ",cm_knn[0][1])
print("False Possitives: ", cm_knn[1][0],"False Negatives: ",cm_knn[1][1])
accuracy_knn=accuracy_score(y_test,y_pred)
print("Training Accuracy: ",y_trainpred)
print("KNN Accuracy: ",accuracy_knn)

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
svc=SVC()
svc.fit(X_train,y_train)

# %%
y_pred=svc.predict(X_test)
y_trainpred=svc.predict(X_train)

# %% [markdown]
# ### Confusion Matrix and Accuracy for SVM

# %%
cm_svc=confusion_matrix(y_test,y_pred)
print("True Possitives: ", cm_svc[0][0],"True Negatives: ",cm_svc[0][1])
print("False Possitives: ", cm_svc[1][0],"False Negatives: ",cm_svc[1][1])
accuracy_svc=accuracy_score(y_test,y_pred)
print("Training Accuracy: ",y_trainpred)
print("SVM Accuracy: ",accuracy_svc)

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %% [markdown]
# # XGBoost Classifier

# %%
from xgboost import XGBClassifier

# %%
xgb=XGBClassifier()
xgb.fit(X_train,y_train)

# %%
y_pred=xgb.predict(X_test)
y_trainpred=xgb.predict(X_train)

# %% [markdown]
# ### Confusion Matrix and Accuracy for XGB Classifier

# %%
cm_xgb=confusion_matrix(y_test,y_pred)
print("True Possitives: ", cm_xgb[0][0],"True Negatives: ",cm_xgb[0][1])
print("False Possitives: ", cm_xgb[1][0],"False Negatives: ",cm_xgb[1][1])
accuracy_xgb=accuracy_score(y_test,y_pred)
print("Training Accuracy: ",y_trainpred)
print("XGB Accuracy: ",accuracy_xgb)

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %% [markdown]
# # Models Evaluation

# %%
data = {'name': ['Decion tree Classifier', 'Rand Forest Classifier', 'KNN Classifier', 'SVM Classifier','XGB Classifier'],
        'accuracy': [accuracy_dtree*100,accuracy_rfc*100,accuracy_knn*100,accuracy_svc*100,accuracy_xgb*100]} 
new = pd.DataFrame.from_dict(data)

# %%
new

# %%
final_df = new.sort_values(by=['accuracy'], ascending=False)
final_df

# %%
plt.barh(final_df['name'],final_df['accuracy'], align='center')
plt.xlabel("Accuracy")
plt.ylabel("Machine Learning Model")
plt.show()

# %% [markdown]
# #
